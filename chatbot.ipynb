# %% [markdown]
# # [구글 AI 기반 서비스 개발] 개인 미니 프로젝트
# * **이름:** 이주혁
# * **선택 모델:** Google Gemini-2.5-flash
# * **프로젝트 목표:** 과제 안내 PDF의 내용을 학습하여, 과제에 대한 질문에 답변하는 RAG 챗봇 데모를 개발합니다.

# %%
# --- 1. 필요한 라이브러리 설치 ---
# 이 셀은 최초 한 번만 실행하면 됩니다.
# !pip install --upgrade langchain langchain-openai langchain-google-genai langchain-text-splitters pypdf chromadb python-dotenv

# --- 2. 필요한 모든 모듈 Import ---
import os
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import HumanMessage, AIMessage
from langchain_google_genai import ChatGoogleGenerativeAI

# .env 파일에서 API 키 로드
load_dotenv()
# Out:
# Requirement already satisfied: langchain in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (1.0.3)
# Requirement already satisfied: langchain-openai in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (1.0.2)
# Requirement already satisfied: langchain-google-genai in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (3.0.1)
# Requirement already satisfied: langchain-text-splitters in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (1.0.0)
# Requirement already satisfied: pypdf in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (6.1.3)
# Requirement already satisfied: chromadb in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (1.3.2)
# Requirement already satisfied: python-dotenv in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (1.2.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain) (2.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (0.4.34)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.11.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-openai) (2.3.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.11.0)
# Requirement already satisfied: sniffio in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.18)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.7.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-google-genai) (0.9.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (2.41.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (6.32.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain-google-genai) (0.6.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.37.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (2.3.3)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (1.23.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (1.37.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (0.19.2)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: pyproject_hooks in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: sympy in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.58b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.35.3)
# Requirement already satisfied: filelock in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.9.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\joohy\anaconda3\envs\rag_chatbot_project\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# True

# %%
# 

PDF_FILE_PATH = "2025 10 (공유) 강원대 중간 고사 내용.pdf"
DB_PERSIST_DIRECTORY = "my_vector_db"

def load_and_split_documents(file_path):
    print(f"'{file_path}' 파일에서 PDF를 로드합니다...")
    loader = PyPDFLoader(file_path)
    documents = loader.load()
    
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    split_documents = text_splitter.split_documents(documents)
    print(f"✅ 문서 로드 및 분할 완료. (총 {len(split_documents)}개 청크)")
    return split_documents

# DB 폴더가 없으면 문서를 새로 로드하고, 있으면 건너뜁니다.
if not os.path.exists(DB_PERSIST_DIRECTORY):
    split_docs = load_and_split_documents(PDF_FILE_PATH)
else:
    split_docs = None # DB가 이미 있으므로 새로 로드할 필요 없음
    print("PDF 로드 및 분할 건너뛰기 (기존 DB 사용)")
# Out:
# PDF 로드 및 분할 건너뛰기 (기존 DB 사용)

# %%
embeddings = OpenAIEmbeddings()

if not os.path.exists(DB_PERSIST_DIRECTORY):
    print(f"DB를 새로 생성합니다.")
    vectorstore = Chroma.from_documents(
        documents=split_docs,
        embedding=embeddings,
        persist_directory=DB_PERSIST_DIRECTORY
    )
    print("DB 생성이 완료되었습니다.")
else:
    print(f"기존 DB를 불러옵니다. (경로: {DB_PERSIST_DIRECTORY})")
    vectorstore = Chroma(
        persist_directory=DB_PERSIST_DIRECTORY,
        embedding_function=embeddings
    )
    print("DB 로딩이 완료되었습니다.")

# DB에서 검색 기능을 수행할 Retriever를 준비
retriever = vectorstore.as_retriever()
# Out:
# 기존 DB를 불러옵니다. (경로: my_vector_db)
# DB 로딩이 완료되었습니다.

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", streaming=True)
print(f"LLM 준비 완료: {llm.model}")
# Out:
# LLM 준비 완료: models/gemini-2.5-flash

# %%
system_prompt = """
당신은 주어진 내용을 바탕으로 사용자의 질문에 답변하는 친절한 AI 어시스턴트입니다.
이전 대화 내용을 참고하여 질문에 대한 답변을 생성하세요.
주어진 내용에서만 답변을 찾아야 하며, 내용을 지어내서는 안 됩니다.

내용:
{context}
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{question}")
])

print("프롬프트 템플릿 준비 완료")
# Out:
# 프롬프트 템플릿 준비 완료

# %%
# langchain 파이프라인을 이용한 RAG 체인 생성
rag_chain = (
    RunnablePassthrough.assign(context=lambda x: retriever.invoke(x["question"]))
    | prompt
    | llm
    | StrOutputParser()
)

print("RAG 체인 생성 완료")
# Out:
# RAG 체인 생성 완료

# %%
# 대화 기록을 저장할 리스트 (메모리)
chat_history = []

def ask_chatbot(query):
    """
    질문을 받아 챗봇을 실행하고, 스트리밍으로 답변을 출력하며,
    대화 기록을 업데이트하는 함수
    """
    
    print("답변: ", end="", flush=True)
    
    # RAG 체인 실행
    response_stream = rag_chain.stream({
        "question": query,
        "chat_history": chat_history
    })
    
    full_answer = ""
    for chunk in response_stream:
        print(chunk, end="", flush=True)
        full_answer += chunk
    
    # 대화 기록 업데이트
    chat_history.append(HumanMessage(content=query))
    chat_history.append(AIMessage(content=full_answer))
    
    print("\n" + "-"*50)

print("대화 메모리 및 실행 함수 준비 완료")
# Out:
# 대화 메모리 및 실행 함수 준비 완료

# %%
ask_chatbot("과제 제출일이 언제까지지???")
# Out:
# 답변: 과제 제출 기한은 **2025년 11월 4일 (화요일)**까지입니다.
# --------------------------------------------------

# %%
ask_chatbot("제출할 내용은 뭐가 있어???  300자 이내로 말해줘")
# Out:
# 답변: 제출할 내용은 총 3가지입니다.
# 1.  **3분 데모 발표 영상** (mp4 등 일반적인 동영상 형식)
# 2.  **프로젝트 소스코드** (공개 GitHub Repository 링크, API Key 등 중요 정보가 들어가지 않도록 주의)
# 3.  **교수에게 하고 싶은 질문** (구글 폼을 통해 제출)
# --------------------------------------------------

# %%
ask_chatbot("이전에 내가 뭘 물어봤었지??? 500자 이내로 말해줄래??")
# Out:
# 답변: 이전에 사용자님께서 질문하셨던 내용은 다음과 같습니다:
#
# 1.  **과제 제출일이 언제까지인지** 궁금해하셨습니다.
# 2.  **제출할 내용이 무엇인지** 300자 이내로 알려달라고 요청하셨습니다.
# --------------------------------------------------
